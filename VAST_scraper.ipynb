# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
protein_seeds = ['3M5L', '1YPH']

# %% [markdown]
# ## Define a function for extracting info from every row (\<tr> component)

# %%
def extract_values_from_row(row):
    row_html = row.get_attribute('outerHTML')
    row_bsoup = BeautifulSoup(row_html, 'html.parser')
    
    # extract string from each <td> component (each <td> = a column value)
    name = row_bsoup.find('td', {'class': 'c2'}).string
    description = row_bsoup.find('td', {'class': 'c3'}).string
    taxonomy = row_bsoup.find('td', {'class': 'c31'}).string
    aligned_protein = row_bsoup.find('td', {'class': 'cx cx1'}).string
    rmsd = row_bsoup.find('td', {'class': 'cx cx2'}).string
    aligned_residues = row_bsoup.find('td', {'class': 'cx cx3 vtable-sorted'}).string
    seq_id = row_bsoup.find('td', {'class': 'cx cx4'}).string
    
    return name, description, taxonomy, aligned_protein, rmsd, aligned_residues, seq_id

# %% [markdown]
# ## Create webdriver instance and connect to URL

# %%
driver = webdriver.Firefox()

# %% [markdown]
# ## Find total amount of rows in search query, and change table length (delete soon)

# %%
row_count_elem = driver.find_element_by_id("page_total_rows")
row_count = row_count_elem.get_attribute('innerHTML')

# %%
search_bar = driver.find_element_by_name("vtable_length")

# %%
search_bar.clear()
search_bar.send_keys(row_count)
search_bar.send_keys(Keys.RETURN)

# %% [markdown]
# ## Now iterate over all protein entries in the table

# %%
proteins = driver.find_elements_by_class_name('even')
proteins_2 = driver.find_elements_by_class_name('odd')
proteins.extend(proteins_2)

# %%
names = []
descriptions = []
taxonomies = []
aligned_proteins = []
rmsds = []
aligned_residues = []
seq_ids = []

# %%
for p in proteins:
    name, des, tax, al_pro, rms, al_res, seq_id = extract_values_from_row(p)
    
    names.append(name)
    descriptions.append(des)
    taxonomies.append(tax)
    aligned_proteins.append(al_pro)
    rmsds.append(rms)
    aligned_residues.append(al_res)
    seq_ids.append(seq_id)

# %% [markdown]
# ## Create pandas dataframe after generating dictionary of all the lists

# %%
protein_dict = {
    'name': names,
    'description': descriptions,
    'taxonomy': taxonomies,
    'aligned_protein': aligned_proteins,
    'rmsd': rmsds,
    'aligned_residue': aligned_residues,
    'sequence_id': seq_ids
}

# %%
df = pd.DataFrame(protein_dict)

# %% [markdown]
# # Create a function to loop above process for all matching protein codenames

# %%
# list of unknown_proteins gets updated with every pass of the algo
def get_all_matching_proteins(unknown_proteins: list):
    count = 0
    
    known_proteins = []
    
    names = []
    descriptions = []
    taxonomies = []
    aligned_proteins = []
    rmsds = []
    aligned_residues = [] 
    seq_ids = []
    seed_proteins = []
        
    while unknown_proteins and count < 692: # while unknown proteins is not empty
        seed_protein = unknown_proteins.pop(0)
        
        if seed_protein not in known_proteins:
            known_proteins.append(seed_protein) # Current protein we're searching now known

            driver.get("https://www.ncbi.nlm.nih.gov/Structure/vastplus/vastplus.cgi?uid=" + seed_protein)
            row_count_elem = driver.find_element_by_id("page_total_rows")
            row_count = row_count_elem.get_attribute('innerHTML')
            search_bar = driver.find_element_by_name("vtable_length")
            search_bar.clear()
            search_bar.send_keys(row_count)
            search_bar.send_keys(Keys.RETURN)

            proteins = driver.find_elements_by_class_name('even')
            proteins_2 = driver.find_elements_by_class_name('odd')
            proteins.extend(proteins_2)

            rejected_protein_count = 0
            for p in proteins:
                name, des, tax, al_pro, rms, al_res, seq_id = extract_values_from_row(p)

                if name not in known_proteins and name not in unknown_proteins: 
                    # 2nd condition is for whether protein is already in our search list (unknown proteins)
                    names.append(name)
                    descriptions.append(des)
                    taxonomies.append(tax)
                    aligned_proteins.append(al_pro)
                    rmsds.append(rms)
                    aligned_residues.append(al_res)
                    seq_ids.append(seq_id)
                    seed_proteins.append(seed_protein)
                    
                    unknown_proteins.append(name) # add protein to list of proteins we need to search
                else:
                    rejected_protein_count += 1
                
                    
            count += 1
            print('Finished searching protein #' + str(count) + ': ' + seed_protein + \
                  '; Matched proteins already seen: ' + str(rejected_protein_count))
        
        if count % 50 == 0:
            print("-------------------")
            print("Writing contents to disk and flushing all lists")
            print("-------------------")
            
            protein_dict = {
                'name': names,
                'seed_protein': seed_proteins,
                'description': descriptions,
                'taxonomy': taxonomies,
                'aligned_protein': aligned_proteins,
                'rmsd': rmsds,
                'aligned_residue': aligned_residues,
                'sequence_id': seq_ids
            }
    
            df = pd.DataFrame(protein_dict)
            df.to_csv("proteins_" + str(int(count / 50)) + ".csv")
            
            names.clear()
            descriptions.clear()
            taxonomies.clear()
            aligned_proteins.clear()
            rmsds.clear()
            aligned_residues.clear()
            seq_ids.clear()
            seed_proteins.clear()
            
            
                  
    print('Proteins searched for: ' + str(count))
                       
    protein_dict = {
        'name': names,
        'seed_protein': seed_proteins,
        'description': descriptions,
        'taxonomy': taxonomies,
        'aligned_protein': aligned_proteins,
        'rmsd': rmsds,
        'aligned_residue': aligned_residues,
        'sequence_id': seq_ids
    }
    
    df = pd.DataFrame(protein_dict)
    df.to_csv("proteins_" + str(int(count / 50)) + ".csv")
    
    return df

# %%
df = get_all_matching_proteins(['3M5L'])
# Out:
# Finished searching protein #1: 3M5L; Matched proteins already seen: 0
# Finished searching protein #2: 3SU3; Matched proteins already seen: 659
# Finished searching protein #3: 3RC4; Matched proteins already seen: 715
# Finished searching protein #4: 6P6R; Matched proteins already seen: 720
# Finished searching protein #5: 3SU2; Matched proteins already seen: 788
# Finished searching protein #6: 6DIR; Matched proteins already seen: 559
# Finished searching protein #7: 6DIV; Matched proteins already seen: 753
# Finished searching protein #8: 6DIS; Matched proteins already seen: 771
# Finished searching protein #9: 6DIW; Matched proteins already seen: 659
# Finished searching protein #10: 4WH8; Matched proteins already seen: 756
# Finished searching protein #11: 6P6L; Matched proteins already seen: 976
# Finished searching protein #12: 6PIV; Matched proteins already seen: 1063
# Finished searching protein #13: 3SV9; Matched proteins already seen: 1078
# Finished searching protein #14: 6PIY; Matched proteins already seen: 885
# Finished searching protein #15: 6CVY; Matched proteins already seen: 748
# Finished searching protein #16: 6CVX; Matched proteins already seen: 751
# Finished searching protein #17: 6PIX; Matched proteins already seen: 1245
# Finished searching protein #18: 3SV6; Matched proteins already seen: 1281
# Finished searching protein #19: 3M5N; Matched proteins already seen: 1028
# Finished searching protein #20: 5VP9; Matched proteins already seen: 647
# Finished searching protein #21: 5EPN; Matched proteins already seen: 702
# Finished searching protein #22: 6DIQ; Matched proteins already seen: 670
# Finished searching protein #23: 3RC5; Matched proteins already seen: 515
# Finished searching protein #24: 6PJ2; Matched proteins already seen: 1137
# Finished searching protein #25: 6P6Q; Matched proteins already seen: 1383
# Finished searching protein #26: 6UE3; Matched proteins already seen: 838
# Finished searching protein #27: 5EQS; Matched proteins already seen: 145
# Finished searching protein #28: 6NZV; Matched proteins already seen: 910
# Finished searching protein #29: 4NWL; Matched proteins already seen: 1671
# Finished searching protein #30: 4WF8; Matched proteins already seen: 364
# Finished searching protein #31: 3SU4; Matched proteins already seen: 608
# Finished searching protein #32: 6P6S; Matched proteins already seen: 940
# Finished searching protein #33: 3O8B; Matched proteins already seen: 207
# Finished searching protein #34: 1CU1; Matched proteins already seen: 426
# Finished searching protein #35: 3O8R; Matched proteins already seen: 462
# Finished searching protein #36: 5FPY; Matched proteins already seen: 479
# Finished searching protein #37: 4B71; Matched proteins already seen: 489
# Finished searching protein #38: 4B76; Matched proteins already seen: 450
# Finished searching protein #39: 6BQJ; Matched proteins already seen: 529
# Finished searching protein #40: 4A1X; Matched proteins already seen: 1503
# Finished searching protein #41: 6P6V; Matched proteins already seen: 558
# Finished searching protein #42: 5FPS; Matched proteins already seen: 477
# Finished searching protein #43: 3O8D; Matched proteins already seen: 414
# Finished searching protein #44: 3KEE; Matched proteins already seen: 2143
# Finished searching protein #45: 4I32; Matched proteins already seen: 1161
# Finished searching protein #46: 4TYD; Matched proteins already seen: 2394
# Finished searching protein #47: 4I31; Matched proteins already seen: 1106
# Finished searching protein #48: 1N1L; Matched proteins already seen: 1524
# Finished searching protein #49: 2GVF; Matched proteins already seen: 1423
# Finished searching protein #50: 3LON; Matched proteins already seen: 2136
# -------------------
# Writing contents to disk and flushing all lists
# -------------------
# Finished searching protein #51: 3P8N; Matched proteins already seen: 1678
# Finished searching protein #52: 3KNX; Matched proteins already seen: 2034
# Finished searching protein #53: 3OYP; Matched proteins already seen: 2440
# Finished searching protein #54: 1DY8; Matched proteins already seen: 2622
# Finished searching protein #55: 4KTC; Matched proteins already seen: 2618
# Finished searching protein #56: 6P6Z; Matched proteins already seen: 2325
# Finished searching protein #57: 2XCN; Matched proteins already seen: 2636
# Finished searching protein #58: 2XNI; Matched proteins already seen: 2584
# Finished searching protein #59: 2XCF; Matched proteins already seen: 2721
# Finished searching protein #60: 1RGQ; Matched proteins already seen: 2198
# Finished searching protein #61: 2A4G; Matched proteins already seen: 2600
# Finished searching protein #62: 1RTL; Matched proteins already seen: 2775
# Finished searching protein #63: 2P59; Matched proteins already seen: 2525
# Finished searching protein #64: 2A4Q; Matched proteins already seen: 2583
# Finished searching protein #65: 2OC7; Matched proteins already seen: 2347
# Finished searching protein #66: 2OC1; Matched proteins already seen: 2803
# Finished searching protein #67: 2F9U; Matched proteins already seen: 2269
# Finished searching protein #68: 2OC8; Matched proteins already seen: 2546
# Finished searching protein #69: 2F9V; Matched proteins already seen: 2738
# Finished searching protein #70: 4M9M; Matched proteins already seen: 743
# Finished searching protein #71: 5LC0; Matched proteins already seen: 1899
# Finished searching protein #72: 6FE6; Matched proteins already seen: 2126
# Finished searching protein #73: 3LKW; Matched proteins already seen: 794
# Finished searching protein #74: 3L6P; Matched proteins already seen: 704
# Finished searching protein #75: 2M9P; Matched proteins already seen: 411
# Finished searching protein #76: 1P12; Matched proteins already seen: 1803
# Finished searching protein #77: 1QRX; Matched proteins already seen: 1980
# Finished searching protein #78: 1P04; Matched proteins already seen: 2022
# Finished searching protein #79: 2H5C; Matched proteins already seen: 1981
# Finished searching protein #80: 1P10; Matched proteins already seen: 2001
# Finished searching protein #81: 1ANE; Matched proteins already seen: 2892
# Finished searching protein #82: 1TLD; Matched proteins already seen: 2870
# Finished searching protein #83: 6KK2; Matched proteins already seen: 2134
# Finished searching protein #84: 6L4Z; Matched proteins already seen: 2075
# Finished searching protein #85: 1BOQ; Matched proteins already seen: 2013
# Finished searching protein #86: 3M7U; Matched proteins already seen: 2208
# Finished searching protein #87: 5H4I; Matched proteins already seen: 1274
# Finished searching protein #88: 3LT3; Matched proteins already seen: 2825
# Finished searching protein #89: 1SLV; Matched proteins already seen: 2888
# Finished searching protein #90: 5H6V; Matched proteins already seen: 2314
# Finished searching protein #91: 1P06; Matched proteins already seen: 1864
# Finished searching protein #92: 2GGV; Matched proteins already seen: 2500
# Finished searching protein #93: 8LPR; Matched proteins already seen: 1800
# Finished searching protein #94: 5ZOB; Matched proteins already seen: 2703
# Finished searching protein #95: 3E90; Matched proteins already seen: 2250
# Finished searching protein #96: 2ULL; Matched proteins already seen: 2230
# Finished searching protein #97: 1GBK; Matched proteins already seen: 1753
# Finished searching protein #98: 1GBD; Matched proteins already seen: 1925
# Finished searching protein #99: 3K6Z; Matched proteins already seen: 2882
# Finished searching protein #100: 6JPW; Matched proteins already seen: 2243
# -------------------
# Writing contents to disk and flushing all lists
# -------------------
# Finished searching protein #101: 6KPQ; Matched proteins already seen: 2071
# Finished searching protein #102: 6EAU; Matched proteins already seen: 3013
# Finished searching protein #103: 4ABJ; Matched proteins already seen: 2891
# Finished searching protein #104: 6L50; Matched proteins already seen: 1505
# Finished searching protein #105: 5ZMS; Matched proteins already seen: 1760
# Finished searching protein #106: 1P11; Matched proteins already seen: 1841
# Finished searching protein #107: 3M7T; Matched proteins already seen: 1920
# Finished searching protein #108: 1GBA; Matched proteins already seen: 2141
# Finished searching protein #109: 2LPR; Matched proteins already seen: 2066
# Finished searching protein #110: 3URC; Matched proteins already seen: 2154
# Finished searching protein #111: 4A8B; Matched proteins already seen: 2412
# Finished searching protein #112: 5YOF; Matched proteins already seen: 1881
# Finished searching protein #113: 5GPI; Matched proteins already seen: 2145
# Finished searching protein #114: 1GBE; Matched proteins already seen: 2006
# Finished searching protein #115: 5LPR; Matched proteins already seen: 1970
# Finished searching protein #116: 3GY3; Matched proteins already seen: 2916
# Finished searching protein #117: 1P03; Matched proteins already seen: 2075
# Finished searching protein #118: 3OTP; Matched proteins already seen: 2450
# Finished searching protein #119: 6KK6; Matched proteins already seen: 2062
# Finished searching protein #120: 1P02; Matched proteins already seen: 1959
# Finished searching protein #121: 3CP7; Matched proteins already seen: 2850
# Finished searching protein #122: 4A8A; Matched proteins already seen: 3791
# Finished searching protein #123: 5MRS; Matched proteins already seen: 1297
# Finished searching protein #124: 5YOD; Matched proteins already seen: 2106
# Finished searching protein #125: 2FP7; Matched proteins already seen: 2151
# Finished searching protein #126: 4A8C; Matched proteins already seen: 2428
# Finished searching protein #127: 2OUA; Matched proteins already seen: 2216
# Finished searching protein #128: 4NSY; Matched proteins already seen: 2909
# Finished searching protein #129: 1ARB; Matched proteins already seen: 2724
# Finished searching protein #130: 3KID; Matched proteins already seen: 2928
# Finished searching protein #131: 4GPG; Matched proteins already seen: 2850
# Finished searching protein #132: 2W5E; Matched proteins already seen: 3007
# Finished searching protein #133: 4AFS; Matched proteins already seen: 2954
# Finished searching protein #134: 6UM3; Matched proteins already seen: 1548
# Finished searching protein #135: 2O8T; Matched proteins already seen: 2948
# Finished searching protein #136: 6TYA; Matched proteins already seen: 2680
# Finished searching protein #137: 5YVW; Matched proteins already seen: 459
# Finished searching protein #138: 1SLX; Matched proteins already seen: 2938
# Finished searching protein #139: 1EZS; Matched proteins already seen: 2925
# Finished searching protein #140: 5GIB; Matched proteins already seen: 2936
# Finished searching protein #141: 4NSV; Matched proteins already seen: 2951
# Finished searching protein #142: 3V0X; Matched proteins already seen: 2919
# Finished searching protein #143: 1UTK; Matched proteins already seen: 2948
# Finished searching protein #144: 1SMF; Matched proteins already seen: 2958
# Finished searching protein #145: 1TYN; Matched proteins already seen: 2920
# Finished searching protein #146: 1BTW; Matched proteins already seen: 2892
# Finished searching protein #147: 6FF0; Matched proteins already seen: 2739
# Finished searching protein #148: 1HYL; Matched proteins already seen: 2967
# Finished searching protein #149: 1FY8; Matched proteins already seen: 2937
# Finished searching protein #150: 3VEQ; Matched proteins already seen: 2954
# -------------------
# Writing contents to disk and flushing all lists
# -------------------
# Finished searching protein #151: 1HAV; Matched proteins already seen: 2641
# Finished searching protein #152: 3H7T; Matched proteins already seen: 2949
# Finished searching protein #153: 5TFN; Matched proteins already seen: 960
# Finished searching protein #154: 4NFE; Matched proteins already seen: 3020
# Finished searching protein #155: 6DWH; Matched proteins already seen: 2142
# Finished searching protein #156: 1G36; Matched proteins already seen: 2901
# Finished searching protein #157: 3PTN; Matched proteins already seen: 2926
# Finished searching protein #158: 1ZZZ; Matched proteins already seen: 2932
# Finished searching protein #159: 5Y28; Matched proteins already seen: 2974
# Finished searching protein #160: 2SGA; Matched proteins already seen: 1898
# Finished searching protein #161: 1L1N; Matched proteins already seen: 2791
# Finished searching protein #162: 5LPE; Matched proteins already seen: 3069
# Finished searching protein #163: 1TIO; Matched proteins already seen: 2954
# Finished searching protein #164: 1C2L; Matched proteins already seen: 2927
# Finished searching protein #165: 1OYQ; Matched proteins already seen: 2937
# Finished searching protein #166: 1LQE; Matched proteins already seen: 2884
# Finished searching protein #167: 4J2Y; Matched proteins already seen: 3291
# Finished searching protein #168: 1XUJ; Matched proteins already seen: 2933
# Finished searching protein #169: 1PPC; Matched proteins already seen: 2899
# Finished searching protein #170: 3NWU; Matched proteins already seen: 2983
# Finished searching protein #171: 2SGD; Matched proteins already seen: 2713
# Finished searching protein #172: 6KU7; Matched proteins already seen: 2801
# Finished searching protein #173: 5Y2D; Matched proteins already seen: 2846
# Finished searching protein #174: 6FFN; Matched proteins already seen: 2845
# Finished searching protein #175: 4K69; Matched proteins already seen: 2968
# Finished searching protein #176: 1V2S; Matched proteins already seen: 2874
# Finished searching protein #177: 1YP9; Matched proteins already seen: 2886
# Finished searching protein #178: 1JRS; Matched proteins already seen: 2962
# Finished searching protein #179: 1DVA; Matched proteins already seen: 2943
# Finished searching protein #180: 2FXR; Matched proteins already seen: 2944
# Finished searching protein #181: 2FX6; Matched proteins already seen: 2861
# Finished searching protein #182: 3A8D; Matched proteins already seen: 2927
# Finished searching protein #183: 1XUF; Matched proteins already seen: 2931
# Finished searching protein #184: 3GDS; Matched proteins already seen: 2773
# Finished searching protein #185: 6KZ0; Matched proteins already seen: 3114
# Finished searching protein #186: 1SGP; Matched proteins already seen: 2904
# Finished searching protein #187: 4SGB; Matched proteins already seen: 2360
# Finished searching protein #188: 5YVU; Matched proteins already seen: 708
# Finished searching protein #189: 1A5H; Matched proteins already seen: 3026
# Finished searching protein #190: 2AS9; Matched proteins already seen: 2892
# Finished searching protein #191: 1WUN; Matched proteins already seen: 3336
# Finished searching protein #192: 4WWY; Matched proteins already seen: 2996
# Finished searching protein #193: 4AB8; Matched proteins already seen: 2933
# Finished searching protein #194: 1QL7; Matched proteins already seen: 2928
# Finished searching protein #195: 3GY2; Matched proteins already seen: 2914
# Finished searching protein #196: 2AGG; Matched proteins already seen: 2874
# Finished searching protein #197: 1G3B; Matched proteins already seen: 2879
# Finished searching protein #198: 2AEI; Matched proteins already seen: 3227
# Finished searching protein #199: 1QBN; Matched proteins already seen: 2917
# Finished searching protein #200: 1C2H; Matched proteins already seen: 2879
# -------------------
# Writing contents to disk and flushing all lists
# -------------------
# Finished searching protein #201: 1QBO; Matched proteins already seen: 2932
# Finished searching protein #202: 2R3Y; Matched proteins already seen: 2879
# Finished searching protein #203: 6KU8; Matched proteins already seen: 2804
# Finished searching protein #204: 5NFS; Matched proteins already seen: 2830
# Finished searching protein #205: 5GSO; Matched proteins already seen: 2882
# Finished searching protein #206: 2AIP; Matched proteins already seen: 2910
# Finished searching protein #207: 3F6U; Matched proteins already seen: 2987
# Finished searching protein #208: 2HLC; Matched proteins already seen: 2940
# Finished searching protein #209: 1TAW; Matched proteins already seen: 3033
# Finished searching protein #210: 1O3J; Matched proteins already seen: 2865
# Finished searching protein #211: 3UWI; Matched proteins already seen: 2861
# Finished searching protein #212: 5GXJ; Matched proteins already seen: 1403
# Finished searching protein #213: 4IW4; Matched proteins already seen: 2929
# Finished searching protein #214: 2A7H; Matched proteins already seen: 2903
# Finished searching protein #215: 1SBW; Matched proteins already seen: 2896
# Finished searching protein #216: 1MTV; Matched proteins already seen: 2872
# Finished searching protein #217: 5E0J; Matched proteins already seen: 2554
# Finished searching protein #218: 1VCW; Matched proteins already seen: 2865
# Finished searching protein #219: 3GCN; Matched proteins already seen: 2715
# Finished searching protein #220: 1SGE; Matched proteins already seen: 3141
# Finished searching protein #221: 5DPA; Matched proteins already seen: 2860
# Finished searching protein #222: 2ZTX; Matched proteins already seen: 2822
# Finished searching protein #223: 3ZYE; Matched proteins already seen: 2833
# Finished searching protein #224: 4X2V; Matched proteins already seen: 2415
# Finished searching protein #225: 1TPO; Matched proteins already seen: 2952
# Finished searching protein #226: 1C2D; Matched proteins already seen: 2924
# Finished searching protein #227: 1K1J; Matched proteins already seen: 2931
# Finished searching protein #228: 1F5L; Matched proteins already seen: 2756
# Finished searching protein #229: 1GJB; Matched proteins already seen: 2846
# Finished searching protein #230: 1A0L; Matched proteins already seen: 2786
# Finished searching protein #231: 3LGI; Matched proteins already seen: 2954
# Finished searching protein #232: 2QF0; Matched proteins already seen: 2975
# Finished searching protein #233: 2Z9I; Matched proteins already seen: 2821
# Finished searching protein #234: 6Q24; Matched proteins already seen: 2753
# Finished searching protein #235: 3ZYD; Matched proteins already seen: 2827
# Finished searching protein #236: 1Z6J; Matched proteins already seen: 3366
# Finished searching protein #237: 4ASH; Matched proteins already seen: 2588
# Finished searching protein #238: 1HCG; Matched proteins already seen: 2904
# Finished searching protein #239: 5L2Z; Matched proteins already seen: 2954
# Finished searching protein #240: 2BZA; Matched proteins already seen: 2895
# Finished searching protein #241: 4E7N; Matched proteins already seen: 2911
# Finished searching protein #242: 1K1L; Matched proteins already seen: 2932
# Finished searching protein #243: 1O3O; Matched proteins already seen: 2927
# Finished searching protein #244: 1L1J; Matched proteins already seen: 2918
# Finished searching protein #245: 2RCE; Matched proteins already seen: 2966
# Finished searching protein #246: 1Y8T; Matched proteins already seen: 2690
# Finished searching protein #247: 6FFS; Matched proteins already seen: 2844
# Finished searching protein #248: 2AIQ; Matched proteins already seen: 2947
# Finished searching protein #249: 4MPX; Matched proteins already seen: 2607
# Finished searching protein #250: 4BTT; Matched proteins already seen: 2942
# -------------------
# Writing contents to disk and flushing all lists
# -------------------
# Finished searching protein #251: 1FON; Matched proteins already seen: 3026
# Finished searching protein #252: 2TGD; Matched proteins already seen: 2945
# Finished searching protein #253: 3W95; Matched proteins already seen: 250
# Finished searching protein #254: 1GJC; Matched proteins already seen: 2853
# Finished searching protein #255: 4X2X; Matched proteins already seen: 2605
# Finished searching protein #256: 3TJN; Matched proteins already seen: 2963
# Finished searching protein #257: 4O3U; Matched proteins already seen: 3099
# Finished searching protein #258: 2ZCH; Matched proteins already seen: 8898
# Finished searching protein #259: 1WTG; Matched proteins already seen: 3381
# Finished searching protein #260: 4IC6; Matched proteins already seen: 2642
# Finished searching protein #261: 2G00; Matched proteins already seen: 2945
# Finished searching protein #262: 1O5D; Matched proteins already seen: 3589
# Finished searching protein #263: 4X2W; Matched proteins already seen: 2632
# Finished searching protein #264: 4R8T; Matched proteins already seen: 1530
# Finished searching protein #265: 5TG1; Matched proteins already seen: 2750
# Finished searching protein #266: 5HMA; Matched proteins already seen: 2910
# Finished searching protein #267: 5HM9; Matched proteins already seen: 2793
# Finished searching protein #268: 4DCD; Matched proteins already seen: 2888
# Finished searching protein #269: 2HRV; Matched proteins already seen: 574
# Finished searching protein #270: 2QY0; Matched proteins already seen: 2922
# Finished searching protein #271: 4KEL; Matched proteins already seen: 2983
# Finished searching protein #272: 4ZXY; Matched proteins already seen: 2927
# Finished searching protein #273: 1QA0; Matched proteins already seen: 2921
# Finished searching protein #274: 1C1T; Matched proteins already seen: 2879
# Finished searching protein #275: 3UQO; Matched proteins already seen: 2952
# Finished searching protein #276: 1O2H; Matched proteins already seen: 2868
# Finished searching protein #277: 4RR0; Matched proteins already seen: 2906
# Finished searching protein #278: 5ILA; Matched proteins already seen: 2876
# Finished searching protein #279: 1TE0; Matched proteins already seen: 2532
# Finished searching protein #280: 6PYM; Matched proteins already seen: 3039
# Finished searching protein #281: 2WV4; Matched proteins already seen: 1351
# Finished searching protein #282: 3G01; Matched proteins already seen: 2947
# Finished searching protein #283: 2R0K; Matched proteins already seen: 8884
# Finished searching protein #284: 4IN1; Matched proteins already seen: 2627
# Finished searching protein #285: 2EC9; Matched proteins already seen: 6149
# Finished searching protein #286: 2FWW; Matched proteins already seen: 2954
# Finished searching protein #287: 1TON; Matched proteins already seen: 2895
# Finished searching protein #288: 2PSX; Matched proteins already seen: 2982
# Finished searching protein #289: 6Q12; Matched proteins already seen: 2881
# Finished searching protein #290: 2QF3; Matched proteins already seen: 2985
# Finished searching protein #291: 3LGW; Matched proteins already seen: 2776
# Finished searching protein #292: 6A8O; Matched proteins already seen: 1795
# Finished searching protein #293: 4XBC; Matched proteins already seen: 2659
# Finished searching protein #294: 6BIB; Matched proteins already seen: 2716
# Finished searching protein #295: 5E0H; Matched proteins already seen: 2510
# Finished searching protein #296: 3UR6; Matched proteins already seen: 2859
# Finished searching protein #297: 1W0Y; Matched proteins already seen: 3341
# Finished searching protein #298: 5K0H; Matched proteins already seen: 2956
# Finished searching protein #299: 3PMJ; Matched proteins already seen: 2896
# Finished searching protein #300: 6NIR; Matched proteins already seen: 2847
# -------------------
# Writing contents to disk and flushing all lists
# -------------------
# Finished searching protein #301: 4RR1; Matched proteins already seen: 2679
# Finished searching protein #302: 6QMR; Matched proteins already seen: 3003
# Finished searching protein #303: 4K1E; Matched proteins already seen: 2987
# Finished searching protein #304: 4IMQ; Matched proteins already seen: 2655
# Finished searching protein #305: 6QH9; Matched proteins already seen: 2950
# Finished searching protein #306: 4XBB; Matched proteins already seen: 2564
# Finished searching protein #307: 2F9P; Matched proteins already seen: 2645
# Finished searching protein #308: 4MG3; Matched proteins already seen: 332
# Finished searching protein #309: 5T69; Matched proteins already seen: 2735
# Finished searching protein #310: 4RI0; Matched proteins already seen: 2963
# Finished searching protein #311: 4XZY; Matched proteins already seen: 2220
# Finished searching protein #312: 5T6D; Matched proteins already seen: 2690
# Finished searching protein #313: 3S9B; Matched proteins already seen: 2951
# Finished searching protein #314: 1OP0; Matched proteins already seen: 2941
# Finished searching protein #315: 1O2K; Matched proteins already seen: 2868
# Finished searching protein #316: 1QY6; Matched proteins already seen: 2924
# Finished searching protein #317: 3LH1; Matched proteins already seen: 2697
# Finished searching protein #318: 2WZQ; Matched proteins already seen: 356
# Finished searching protein #319: 3V7T; Matched proteins already seen: 2827
# Finished searching protein #320: 6KBR; Matched proteins already seen: 3342
# Finished searching protein #321: 2BDI; Matched proteins already seen: 2953
# Finished searching protein #322: 2XWA; Matched proteins already seen: 3024
# Finished searching protein #323: 4FVD; Matched proteins already seen: 847
# Finished searching protein #324: 2M5T; Matched proteins already seen: 284
# Finished searching protein #325: 3LGU; Matched proteins already seen: 2671
# Finished searching protein #326: 2ZLE; Matched proteins already seen: 2049
# Finished searching protein #327: 5WI6; Matched proteins already seen: 2779
# Finished searching protein #328: 2WUB; Matched proteins already seen: 8811
# Finished searching protein #329: 2XW9; Matched proteins already seen: 10
# Finished searching protein #330: 4IC5; Matched proteins already seen: 10
# Finished searching protein #331: 5TCA; Matched proteins already seen: 10
# Finished searching protein #332: 1TQ0; Matched proteins already seen: 10
# Finished searching protein #333: 5NAT; Matched proteins already seen: 10
# Finished searching protein #334: 2QGR; Matched proteins already seen: 10
# Finished searching protein #335: 1BTH; Matched proteins already seen: 10
# Finished searching protein #336: 2VID; Matched proteins already seen: 10
# Finished searching protein #337: 4INH; Matched proteins already seen: 10
# Finished searching protein #338: 1QA7; Matched proteins already seen: 10
# Finished searching protein #339: 4YOJ; Matched proteins already seen: 10
# Finished searching protein #340: 3J0C; Matched proteins already seen: 1
# Finished searching protein #341: 4CBO; Matched proteins already seen: 10
# Finished searching protein #342: 5NAW; Matched proteins already seen: 10
# Finished searching protein #343: 5FCK; Matched proteins already seen: 10
# Finished searching protein #344: 5TG2; Matched proteins already seen: 10
# Finished searching protein #345: 3UR9; Matched proteins already seen: 10
# Finished searching protein #346: 1SGF; Matched proteins already seen: 10
# Finished searching protein #347: 3FZD; Matched proteins already seen: 10
# Finished searching protein #348: 3SU5; Matched proteins already seen: 10
# Finished searching protein #349: 6C2O; Matched proteins already seen: 10
# Finished searching protein #350: 5EPY; Matched proteins already seen: 10
# -------------------
# Writing contents to disk and flushing all lists
# -------------------
# Finished searching protein #351: 6P6O; Matched proteins already seen: 10
# Finished searching protein #352: 6C2N; Matched proteins already seen: 10
# Finished searching protein #353: 6PJ1; Matched proteins already seen: 10
# Finished searching protein #354: 5EQR; Matched proteins already seen: 10
# Finished searching protein #355: 6DIU; Matched proteins already seen: 10
# Finished searching protein #356: 3SU6; Matched proteins already seen: 10
# Finished searching protein #357: 3SU1; Matched proteins already seen: 10
# Finished searching protein #358: 4WH6; Matched proteins already seen: 10
# Finished searching protein #359: 6CVW; Matched proteins already seen: 10
# Finished searching protein #360: 6PIW; Matched proteins already seen: 10
# Finished searching protein #361: 6PIZ; Matched proteins already seen: 10
# Finished searching protein #362: 3RC6; Matched proteins already seen: 10
# Finished searching protein #363: 3SV7; Matched proteins already seen: 10
# Finished searching protein #364: 6P6M; Matched proteins already seen: 10
# Finished searching protein #365: 3M5O; Matched proteins already seen: 10
# Finished searching protein #366: 3SU0; Matched proteins already seen: 10
# Finished searching protein #367: 6DIT; Matched proteins already seen: 10
# Finished searching protein #368: 5VOJ; Matched proteins already seen: 10
# Finished searching protein #369: 6PIU; Matched proteins already seen: 10
# Finished searching protein #370: 6PJ0; Matched proteins already seen: 10
# Finished searching protein #371: 3M5M; Matched proteins already seen: 10
# Finished searching protein #372: 5ESB; Matched proteins already seen: 10
# Finished searching protein #373: 6NZT; Matched proteins already seen: 10
# Finished searching protein #374: 6C2M; Matched proteins already seen: 10
# Finished searching protein #375: 3SV8; Matched proteins already seen: 10
# Finished searching protein #376: 5EQQ; Matched proteins already seen: 10
# Finished searching protein #377: 6BQK; Matched proteins already seen: 1138
# Finished searching protein #378: 6N4N; Matched proteins already seen: 10
# Finished searching protein #379: 5WDX; Matched proteins already seen: 10
# Finished searching protein #380: 3O8C; Matched proteins already seen: 10
# Finished searching protein #381: 4A92; Matched proteins already seen: 10
# Finished searching protein #382: 4B74; Matched proteins already seen: 482
# Finished searching protein #383: 4B75; Matched proteins already seen: 10
# Finished searching protein #384: 4B73; Matched proteins already seen: 10
# Finished searching protein #385: 5FPT; Matched proteins already seen: 10
# Finished searching protein #386: 4A1T; Matched proteins already seen: 10
# Finished searching protein #387: 4NWK; Matched proteins already seen: 10
# Finished searching protein #388: 5ETX; Matched proteins already seen: 10
# Finished searching protein #389: 4A1V; Matched proteins already seen: 10
# Finished searching protein #390: 4K8B; Matched proteins already seen: 10
# Finished searching protein #391: 4U01; Matched proteins already seen: 10
# Finished searching protein #392: 4B6E; Matched proteins already seen: 10
# Finished searching protein #393: 4I33; Matched proteins already seen: 10
# Finished searching protein #394: 4JMY; Matched proteins already seen: 10
# Finished searching protein #395: 3P8O; Matched proteins already seen: 10
# Finished searching protein #396: 3EYD; Matched proteins already seen: 10
# Finished searching protein #397: 1NS3; Matched proteins already seen: 10
# Finished searching protein #398: 1JXP; Matched proteins already seen: 10
# Finished searching protein #399: 1DY9; Matched proteins already seen: 10
# Finished searching protein #400: 1DXP; Matched proteins already seen: 10
# -------------------
# Writing contents to disk and flushing all lists
# -------------------
# Finished searching protein #401: 1W3C; Matched proteins already seen: 10
# Finished searching protein #402: 6P6T; Matched proteins already seen: 10
# Finished searching protein #403: 3KF2; Matched proteins already seen: 10
# Finished searching protein #404: 2QV1; Matched proteins already seen: 10
# Finished searching protein #405: 3KN2; Matched proteins already seen: 10
# Finished searching protein #406: 2O8M; Matched proteins already seen: 10
# Finished searching protein #407: 2OIN; Matched proteins already seen: 10
# Finished searching protein #408: 1A1R; Matched proteins already seen: 10
# Finished searching protein #409: 2A4R; Matched proteins already seen: 10
# Finished searching protein #410: 2FM2; Matched proteins already seen: 10
# Finished searching protein #411: 2OBQ; Matched proteins already seen: 10
# Finished searching protein #412: 2OC0; Matched proteins already seen: 10
# Finished searching protein #413: 2OBO; Matched proteins already seen: 10
# Finished searching protein #414: 3LOX; Matched proteins already seen: 10
# Finished searching protein #415: 1A1Q; Matched proteins already seen: 10
# Finished searching protein #416: 2YOL; Matched proteins already seen: 10
# Finished searching protein #417: 4M9I; Matched proteins already seen: 10
# Finished searching protein #418: 5IDK; Matched proteins already seen: 10
# Finished searching protein #419: 4M9K; Matched proteins already seen: 10
# Finished searching protein #420: 2WV9; Matched proteins already seen: 10
# Finished searching protein #421: 1TAL; Matched proteins already seen: 10
# Finished searching protein #422: 1P01; Matched proteins already seen: 10
# Finished searching protein #423: 5MRR; Matched proteins already seen: 10
# Finished searching protein #424: 5WOT; Matched proteins already seen: 10
# Finished searching protein #425: 1QRW; Matched proteins already seen: 10
# Finished searching protein #426: 6EAT; Matched proteins already seen: 10
# Finished searching protein #427: 4M9T; Matched proteins already seen: 10
# Finished searching protein #428: 5ZMQ; Matched proteins already seen: 10
# Finished searching protein #429: 6KK5; Matched proteins already seen: 10
# Finished searching protein #430: 3U1I; Matched proteins already seen: 2052
# Finished searching protein #431: 2TRM; Matched proteins already seen: 2945
# Finished searching protein #432: 6KK4; Matched proteins already seen: 10
# Finished searching protein #433: 5YW1; Matched proteins already seen: 10
# Finished searching protein #434: 4M9F; Matched proteins already seen: 10
# Finished searching protein #435: 6EAW; Matched proteins already seen: 10
# Finished searching protein #436: 1O2Q; Matched proteins already seen: 10
# Finished searching protein #437: 6LPR; Matched proteins already seen: 10
# Finished searching protein #438: 1P09; Matched proteins already seen: 10
# Finished searching protein #439: 3U1J; Matched proteins already seen: 10
# Finished searching protein #440: 1GBH; Matched proteins already seen: 10
# Finished searching protein #441: 2H5D; Matched proteins already seen: 10
# Finished searching protein #442: 1GBM; Matched proteins already seen: 10
# Finished searching protein #443: 3QGJ; Matched proteins already seen: 10
# Finished searching protein #444: 1GBI; Matched proteins already seen: 10
# Finished searching protein #445: 1GBF; Matched proteins already seen: 10
# Finished searching protein #446: 6KK3; Matched proteins already seen: 10
# Finished searching protein #447: 4AOQ; Matched proteins already seen: 10
# Finished searching protein #448: 3I29; Matched proteins already seen: 10
# Finished searching protein #449: 4PRO; Matched proteins already seen: 10
# Finished searching protein #450: 3PRO; Matched proteins already seen: 10
# -------------------
# Writing contents to disk and flushing all lists
# -------------------
# Finished searching protein #451: 3LPR; Matched proteins already seen: 1532
# Finished searching protein #452: 3URD; Matched proteins already seen: 10
# Finished searching protein #453: 1GBJ; Matched proteins already seen: 10
# Finished searching protein #454: 1W7X; Matched proteins already seen: 10
# Finished searching protein #455: 1P05; Matched proteins already seen: 2056
# Finished searching protein #456: 3K6Y; Matched proteins already seen: 10
# Finished searching protein #457: 2IJO; Matched proteins already seen: 10
# Finished searching protein #458: 6Y3B; Matched proteins already seen: 10
# Finished searching protein #459: 1GBC; Matched proteins already seen: 10
# Finished searching protein #460: 9LPR; Matched proteins already seen: 10
# Finished searching protein #461: 5T1V; Matched proteins already seen: 10
# Finished searching protein #462: 3URE; Matched proteins already seen: 10
# Finished searching protein #463: 7LPR; Matched proteins already seen: 10
# Finished searching protein #464: 1ZYO; Matched proteins already seen: 10
# Finished searching protein #465: 4TPI; Matched proteins already seen: 10
# Finished searching protein #466: 2ALP; Matched proteins already seen: 10
# Finished searching protein #467: 5JD8; Matched proteins already seen: 10
# Finished searching protein #468: 3PV3; Matched proteins already seen: 10
# Finished searching protein #469: 1SSX; Matched proteins already seen: 10
# Finished searching protein #470: 3A7X; Matched proteins already seen: 10
# Finished searching protein #471: 4XDE; Matched proteins already seen: 10
# Finished searching protein #472: 4YO1; Matched proteins already seen: 10
# Finished searching protein #473: 2GKV; Matched proteins already seen: 10
# Finished searching protein #474: 1ARC; Matched proteins already seen: 10
# Finished searching protein #475: 6MO1; Matched proteins already seen: 10
# Finished searching protein #476: 4INL; Matched proteins already seen: 10
# Finished searching protein #477: 5GJ4; Matched proteins already seen: 10
# Finished searching protein #478: 6MO0; Matched proteins already seen: 10
# Finished searching protein #479: 5TFO; Matched proteins already seen: 10
# Finished searching protein #480: 5PAB; Matched proteins already seen: 10
# Finished searching protein #481: 1TRN; Matched proteins already seen: 10
# Finished searching protein #482: 6MO2; Matched proteins already seen: 10
# Finished searching protein #483: 2RA3; Matched proteins already seen: 10
# Finished searching protein #484: 5K7R; Matched proteins already seen: 10
# Finished searching protein #485: 1OPH; Matched proteins already seen: 4
# Finished searching protein #486: 1TGB; Matched proteins already seen: 10
# Finished searching protein #487: 2R0L; Matched proteins already seen: 10
# Finished searching protein #488: 5ZLZ; Matched proteins already seen: 6
# Finished searching protein #489: 3PYH; Matched proteins already seen: 10
# Finished searching protein #490: 1TRM; Matched proteins already seen: 10
# Finished searching protein #491: 1QB6; Matched proteins already seen: 10
# Finished searching protein #492: 1O3L; Matched proteins already seen: 10
# Finished searching protein #493: 4AFU; Matched proteins already seen: 10
# Finished searching protein #494: 3V12; Matched proteins already seen: 10
# Finished searching protein #495: 6EAX; Matched proteins already seen: 10
# Finished searching protein #496: 2AYW; Matched proteins already seen: 10
# Finished searching protein #497: 4SGA; Matched proteins already seen: 10
# Finished searching protein #498: 2XYA; Matched proteins already seen: 10
# Finished searching protein #499: 5YVV; Matched proteins already seen: 10
# Finished searching protein #500: 1WV7; Matched proteins already seen: 10
# -------------------
# Writing contents to disk and flushing all lists
# -------------------
# Finished searching protein #501: 3LJO; Matched proteins already seen: 10
# Finished searching protein #502: 1XUH; Matched proteins already seen: 10
# Finished searching protein #503: 1TPP; Matched proteins already seen: 10
# Finished searching protein #504: 1O2W; Matched proteins already seen: 10
# Finished searching protein #505: 3SGA; Matched proteins already seen: 10
# Finished searching protein #506: 2B0F; Matched proteins already seen: 10
# Finished searching protein #507: 3SGB; Matched proteins already seen: 10
# Finished searching protein #508: 4NFF; Matched proteins already seen: 10
# Finished searching protein #509: 1Y3U; Matched proteins already seen: 10
# Finished searching protein #510: 1QL8; Matched proteins already seen: 10
# Finished searching protein #511: 4AGK; Matched proteins already seen: 10
# Finished searching protein #512: 2FOM; Matched proteins already seen: 10
# Finished searching protein #513: 5PAI; Matched proteins already seen: 10
# Finished searching protein #514: 6DWF; Matched proteins already seen: 10
# Finished searching protein #515: 2R3U; Matched proteins already seen: 10
# Finished searching protein #516: 3SGQ; Matched proteins already seen: 10
# Finished searching protein #517: 1SGR; Matched proteins already seen: 10
# Finished searching protein #518: 3ZVB; Matched proteins already seen: 10
# Finished searching protein #519: 2VB0; Matched proteins already seen: 10
# Finished searching protein #520: 5BPE; Matched proteins already seen: 10
# Finished searching protein #521: 5UBM; Matched proteins already seen: 10
# Finished searching protein #522: 2CMY; Matched proteins already seen: 10
# Finished searching protein #523: 2QYI; Matched proteins already seen: 10
# Finished searching protein #524: 1OX1; Matched proteins already seen: 10
# Finished searching protein #525: 1O5A; Matched proteins already seen: 10
# Finished searching protein #526: 1O2J; Matched proteins already seen: 10
# Finished searching protein #527: 4ZXX; Matched proteins already seen: 10
# Finished searching protein #528: 1BTX; Matched proteins already seen: 10
# Finished searching protein #529: 1O2V; Matched proteins already seen: 10
# Finished searching protein #530: 1SGC; Matched proteins already seen: 10
# Finished searching protein #531: 1CSO; Matched proteins already seen: 10
# Finished searching protein #532: 5LPF; Matched proteins already seen: 10
# Finished searching protein #533: 4AFZ; Matched proteins already seen: 10
# Finished searching protein #534: 1JBU; Matched proteins already seen: 10
# Finished searching protein #535: 1T31; Matched proteins already seen: 10
# Finished searching protein #536: 3BEU; Matched proteins already seen: 10
# Finished searching protein #537: 4DG4; Matched proteins already seen: 10
# Finished searching protein #538: 2PTN; Matched proteins already seen: 10
# Finished searching protein #539: 4B2C; Matched proteins already seen: 10
# Finished searching protein #540: 1V2L; Matched proteins already seen: 10
# Finished searching protein #541: 1EZU; Matched proteins already seen: 10
# Finished searching protein #542: 1AQ7; Matched proteins already seen: 10
# Finished searching protein #543: 3Q00; Matched proteins already seen: 10
# Finished searching protein #544: 1YYY; Matched proteins already seen: 10
# Finished searching protein #545: 4ABG; Matched proteins already seen: 10
# Finished searching protein #546: 4ABI; Matched proteins already seen: 10
# Finished searching protein #547: 1LTO; Matched proteins already seen: 10
# Finished searching protein #548: 3GDV; Matched proteins already seen: 2846
# Finished searching protein #549: 3ZVA; Matched proteins already seen: 10
# Finished searching protein #550: 2SGQ; Matched proteins already seen: 10
# -------------------
# Writing contents to disk and flushing all lists
# -------------------
# Finished searching protein #551: 4AFQ; Matched proteins already seen: 10
# Finished searching protein #552: 6QFE; Matched proteins already seen: 10
# Finished searching protein #553: 5TQE; Matched proteins already seen: 10
# Finished searching protein #554: 1V2V; Matched proteins already seen: 10
# Finished searching protein #555: 2TBS; Matched proteins already seen: 10
# Finished searching protein #556: 1O38; Matched proteins already seen: 10
# Finished searching protein #557: 6QL0; Matched proteins already seen: 10
# Finished searching protein #558: 2D8W; Matched proteins already seen: 2912
# Finished searching protein #559: 3T28; Matched proteins already seen: 10
# Finished searching protein #560: 1O35; Matched proteins already seen: 10
# Finished searching protein #561: 1WYK; Matched proteins already seen: 10
# Finished searching protein #562: 3PWB; Matched proteins already seen: 10
# Finished searching protein #563: 1SOZ; Matched proteins already seen: 10
# Finished searching protein #564: 3LH3; Matched proteins already seen: 10
# Finished searching protein #565: 4RQZ; Matched proteins already seen: 10
# Finished searching protein #566: 2SGP; Matched proteins already seen: 10
# Finished searching protein #567: 2W7U; Matched proteins already seen: 10
# Finished searching protein #568: 3MH4; Matched proteins already seen: 10
# Finished searching protein #569: 3OSY; Matched proteins already seen: 10
# Finished searching protein #570: 1YF4; Matched proteins already seen: 10
# Finished searching protein #571: 3GY5; Matched proteins already seen: 10
# Finished searching protein #572: 4MTB; Matched proteins already seen: 10
# Finished searching protein #573: 3AAU; Matched proteins already seen: 10
# Finished searching protein #574: 4FVB; Matched proteins already seen: 10
# Finished searching protein #575: 6DZF; Matched proteins already seen: 10
# Finished searching protein #576: 2ZEC; Matched proteins already seen: 10
# Finished searching protein #577: 3GCO; Matched proteins already seen: 10
# Finished searching protein #578: 6EW9; Matched proteins already seen: 10
# Finished searching protein #579: 2SGE; Matched proteins already seen: 10
# Finished searching protein #580: 2ZTZ; Matched proteins already seen: 10
# Finished searching protein #581: 3FZZ; Matched proteins already seen: 10
# Finished searching protein #582: 4UON; Matched proteins already seen: 10
# Finished searching protein #583: 1BZX; Matched proteins already seen: 10
# Finished searching protein #584: 4INK; Matched proteins already seen: 10
# Finished searching protein #585: 1BUI; Matched proteins already seen: 10
# Finished searching protein #586: 1IOE; Matched proteins already seen: 10
# Finished searching protein #587: 4WXV; Matched proteins already seen: 10
# Finished searching protein #588: 1V2M; Matched proteins already seen: 10
# Finished searching protein #589: 3FAN; Matched proteins already seen: 10
# Finished searching protein #590: 3GDU; Matched proteins already seen: 10
# Finished searching protein #591: 3LGV; Matched proteins already seen: 10
# Finished searching protein #592: 2SGF; Matched proteins already seen: 10
# Finished searching protein #593: 1WCZ; Matched proteins already seen: 10
# Finished searching protein #594: 2FLR; Matched proteins already seen: 10
# Finished searching protein #595: 1AMH; Matched proteins already seen: 10
# Finished searching protein #596: 5TQF; Matched proteins already seen: 10
# Finished searching protein #597: 4B2A; Matched proteins already seen: 10
# Finished searching protein #598: 2R2W; Matched proteins already seen: 10
# Finished searching protein #599: 4JYU; Matched proteins already seen: 10
# Finished searching protein #600: 5L30; Matched proteins already seen: 10
# -------------------
# Writing contents to disk and flushing all lists
# -------------------
# Finished searching protein #601: 2LNC; Matched proteins already seen: 10
# Finished searching protein #602: 3RUO; Matched proteins already seen: 10
# Finished searching protein #603: 3GYM; Matched proteins already seen: 10
# Finished searching protein #604: 1SPJ; Matched proteins already seen: 10
# Finished searching protein #605: 2FS8; Matched proteins already seen: 10
# Finished searching protein #606: 3UY9; Matched proteins already seen: 10
# Finished searching protein #607: 4KGA; Matched proteins already seen: 10
# Finished searching protein #608: 2TGP; Matched proteins already seen: 10
# Finished searching protein #609: 1FDP; Matched proteins already seen: 10
# Finished searching protein #610: 5MT4; Matched proteins already seen: 10
# Finished searching protein #611: 4MPV; Matched proteins already seen: 10
# Finished searching protein #612: 5HU6; Matched proteins already seen: 3
# Finished searching protein #613: 2O8L; Matched proteins already seen: 10
# Finished searching protein #614: 5FX6; Matched proteins already seen: 10
# Finished searching protein #615: 2ZCL; Matched proteins already seen: 10
# Finished searching protein #616: 2BDH; Matched proteins already seen: 10
# Finished searching protein #617: 1PYT; Matched proteins already seen: 1
# Finished searching protein #618: 1V2U; Matched proteins already seen: 2882
# Finished searching protein #619: 3PTB; Matched proteins already seen: 10
# Finished searching protein #620: 1MTU; Matched proteins already seen: 10
# Finished searching protein #621: 4IN2; Matched proteins already seen: 10
# Finished searching protein #622: 1V2J; Matched proteins already seen: 10
# Finished searching protein #623: 3NZI; Matched proteins already seen: 10
# Finished searching protein #624: 4FLN; Matched proteins already seen: 10
# Finished searching protein #625: 3NUM; Matched proteins already seen: 10
# Finished searching protein #626: 5MM8; Matched proteins already seen: 10
# Finished searching protein #627: 1W8B; Matched proteins already seen: 10
# Finished searching protein #628: 2A2Q; Matched proteins already seen: 3451
# Finished searching protein #629: 4K8Y; Matched proteins already seen: 10
# Finished searching protein #630: 3TH2; Matched proteins already seen: 10
# Finished searching protein #631: 6O21; Matched proteins already seen: 10
# Finished searching protein #632: 2BDG; Matched proteins already seen: 10
# Finished searching protein #633: 4X8U; Matched proteins already seen: 10
# Finished searching protein #634: 1WQS; Matched proteins already seen: 10
# Finished searching protein #635: 1G9I; Matched proteins already seen: 10
# Finished searching protein #636: 1GVL; Matched proteins already seen: 10
# Finished searching protein #637: 2B7D; Matched proteins already seen: 10
# Finished searching protein #638: 4IMZ; Matched proteins already seen: 10
# Finished searching protein #639: 6NVB; Matched proteins already seen: 10
# Finished searching protein #640: 2ZP0; Matched proteins already seen: 10
# Finished searching protein #641: 1OP8; Matched proteins already seen: 10
# Finished searching protein #642: 5X45; Matched proteins already seen: 10
# Finished searching protein #643: 6BIC; Matched proteins already seen: 10
# Finished searching protein #644: 3M7Q; Matched proteins already seen: 10
# Finished searching protein #645: 1C1P; Matched proteins already seen: 10
# Finished searching protein #646: 6B6I; Matched proteins already seen: 10
# Finished searching protein #647: 1P3E; Matched proteins already seen: 10
# Finished searching protein #648: 4GSO; Matched proteins already seen: 10
# Finished searching protein #649: 5PAF; Matched proteins already seen: 10
# Finished searching protein #650: 5DG6; Matched proteins already seen: 10
# -------------------
# Writing contents to disk and flushing all lists
# -------------------
# Finished searching protein #651: 4YT7; Matched proteins already seen: 10
# Finished searching protein #652: 5T6F; Matched proteins already seen: 10
# Finished searching protein #653: 2FYQ; Matched proteins already seen: 10
# Finished searching protein #654: 2TLD; Matched proteins already seen: 10
# Finished searching protein #655: 3LGY; Matched proteins already seen: 10
# Finished searching protein #656: 5JY0; Matched proteins already seen: 10
# Finished searching protein #657: 2GDD; Matched proteins already seen: 10
# Finished searching protein #658: 4JZD; Matched proteins already seen: 10
# Finished searching protein #659: 1P3C; Matched proteins already seen: 10
# Finished searching protein #660: 3M35; Matched proteins already seen: 2893
# Finished searching protein #661: 4RQY; Matched proteins already seen: 10
# Finished searching protein #662: 3LGT; Matched proteins already seen: 10
# Finished searching protein #663: 3TJO; Matched proteins already seen: 10
# Finished searching protein #664: 6M3C; Matched proteins already seen: 10
# Finished searching protein #665: 2XWB; Matched proteins already seen: 7
# Finished searching protein #666: 2FYR; Matched proteins already seen: 10
# Finished searching protein #667: 1TBR; Matched proteins already seen: 10
# Finished searching protein #668: 6QMT; Matched proteins already seen: 10
# Finished searching protein #669: 4NIV; Matched proteins already seen: 10
# Finished searching protein #670: 1SOT; Matched proteins already seen: 10
# Finished searching protein #671: 1SI5; Matched proteins already seen: 10
# Finished searching protein #672: 4JYV; Matched proteins already seen: 10
# Finished searching protein #673: 4X2Y; Matched proteins already seen: 10
# Finished searching protein #674: 1AO5; Matched proteins already seen: 10
# Finished searching protein #675: 3B8J; Matched proteins already seen: 10
# Finished searching protein #676: 1OP2; Matched proteins already seen: 10
# Finished searching protein #677: 5MT0; Matched proteins already seen: 10
# Finished searching protein #678: 4D9Q; Matched proteins already seen: 10
# Finished searching protein #679: 5B6L; Matched proteins already seen: 10
# Finished searching protein #680: 1AUT; Matched proteins already seen: 10
# Finished searching protein #681: 3MH5; Matched proteins already seen: 10
# Finished searching protein #682: 5NB7; Matched proteins already seen: 10
# Finished searching protein #683: 3PV4; Matched proteins already seen: 10
# Finished searching protein #684: 5NBA; Matched proteins already seen: 10
# Finished searching protein #685: 3D23; Matched proteins already seen: 10
# Finished searching protein #686: 2H9H; Matched proteins already seen: 10
# Finished searching protein #687: 5NB6; Matched proteins already seen: 10
# Finished searching protein #688: 1ORF; Matched proteins already seen: 10
# Finished searching protein #689: 3STI; Matched proteins already seen: 10
# Finished searching protein #690: 2IPH; Matched proteins already seen: 10
# Finished searching protein #691: 4XBD; Matched proteins already seen: 10
# Finished searching protein #692: 5GND; Matched proteins already seen: 10
# Proteins searched for: 692

# %%
df.head() # data collection started at 5:04pm (apprx)
# Out:
#    name seed_protein                                        description  \
# 0  3SU3         3M5L  Crystal structure of NS3/4A protease in comple...
# 1  3RC4         3M5L  Molecular mechanisms of viral and host-cell su...
# 2  6P6R         3M5L  HCV NS3/4A protease domain of genotype 1a3a ch...
# 3  3SU2         3M5L  Crystal structure of NS3/4A protease variant A...
# 4  6DIR         3M5L  Crystal structure of HCV NS3/4A protease in co...
#
#                         taxonomy aligned_protein   rmsd aligned_residue  \
# 0   Hepatitis C virus subtype 1a               1  0.19Å             198
# 1                         Others               1  0.21Å             198
# 2  Hepatitis C virus (isolate 1)               1  0.22Å             198
# 3   Hepatitis C virus subtype 1a               1  0.22Å             198
# 4                  Hepacivirus C               1  0.22Å             198
#
#   sequence_id
# 0        100%
# 1        100%
# 2         98%
# 3         99%
# 4         99%

# %%
df.to_csv("four_protein_searched.csv")

# %%
df_1 = pd.read_csv("proteins_1.csv")
df_2 = pd.read_csv("proteins_2.csv")
df_3 = pd.read_csv("proteins_3.csv")
df_4 = pd.read_csv("proteins_4.csv")
df_5 = pd.read_csv("proteins_5.csv")
df_6 = pd.read_csv("proteins_6.csv")
df_7 = pd.read_csv("proteins_7.csv")
df_8 = pd.read_csv("proteins_8.csv")
df_9 = pd.read_csv("proteins_9.csv")
df_10 = pd.read_csv("proteins_10.csv")
df_11 = pd.read_csv("proteins_11.csv")
df_12 = pd.read_csv("proteins_12.csv")
df_13 = pd.read_csv("proteins_13.csv")

# %%
all_proteins_df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10, df_11, df_12, df_13], ignore_index=True)

# %%
all_proteins_df
# Out:
#       Unnamed: 0  name seed_protein  \
# 0              0  3SU3         3M5L
# 1              1  3RC4         3M5L
# 2              2  6P6R         3M5L
# 3              3  3SU2         3M5L
# 4              4  6DIR         3M5L
# ...          ...   ...          ...
# 16159         17  5MV8         3GDV
# 16160         18  5XBF         3GDV
# 16161          0  5FO7         2XWB
# 16162          1  5O35         2XWB
# 16163          2  2I07         2XWB
#
#                                              description  \
# 0      Crystal structure of NS3/4A protease in comple...
# 1      Molecular mechanisms of viral and host-cell su...
# 2      HCV NS3/4A protease domain of genotype 1a3a ch...
# 3      Crystal structure of NS3/4A protease variant A...
# 4      Crystal structure of HCV NS3/4A protease in co...
# ...                                                  ...
# 16159  Structure Of Human Myosin 7b C-terminal Myth4-...
# 16160  Crystal Structure of Myo7b C-terminal MyTH4-FE...
# 16161  Crystal Structure Of Human Complement C3b At 2...
# 16162           Structure of complement proteins complex
# 16163                     Human Complement Component C3b
#
#                             taxonomy aligned_protein   rmsd aligned_residue  \
# 0       Hepatitis C virus subtype 1a               1  0.19Å             198
# 1                             Others               1  0.21Å             198
# 2      Hepatitis C virus (isolate 1)               1  0.22Å             198
# 3       Hepatitis C virus subtype 1a               1  0.22Å             198
# 4                      Hepacivirus C               1  0.22Å             198
# ...                              ...             ...    ...             ...
# 16159                   Homo sapiens               1  1.30Å              50
# 16160                   Homo sapiens               1  1.30Å              43
# 16161                   Homo sapiens               2  2.10Å            1521
# 16162                   Homo sapiens               2  2.09Å            1530
# 16163                   Homo sapiens               2  2.42Å            1519
#
#       sequence_id
# 0            100%
# 1            100%
# 2             98%
# 3             99%
# 4             99%
# ...           ...
# 16159         30%
# 16160         28%
# 16161        100%
# 16162         99%
# 16163         99%
#
# [16164 rows x 9 columns]

# %%
all_proteins_df = all_proteins_df.drop(columns=['Unnamed: 0'])

# %%
all_proteins_df
# Out:
#        name seed_protein                                        description  \
# 0      3SU3         3M5L  Crystal structure of NS3/4A protease in comple...
# 1      3RC4         3M5L  Molecular mechanisms of viral and host-cell su...
# 2      6P6R         3M5L  HCV NS3/4A protease domain of genotype 1a3a ch...
# 3      3SU2         3M5L  Crystal structure of NS3/4A protease variant A...
# 4      6DIR         3M5L  Crystal structure of HCV NS3/4A protease in co...
# ...     ...          ...                                                ...
# 16159  5MV8         3GDV  Structure Of Human Myosin 7b C-terminal Myth4-...
# 16160  5XBF         3GDV  Crystal Structure of Myo7b C-terminal MyTH4-FE...
# 16161  5FO7         2XWB  Crystal Structure Of Human Complement C3b At 2...
# 16162  5O35         2XWB           Structure of complement proteins complex
# 16163  2I07         2XWB                     Human Complement Component C3b
#
#                             taxonomy aligned_protein   rmsd aligned_residue  \
# 0       Hepatitis C virus subtype 1a               1  0.19Å             198
# 1                             Others               1  0.21Å             198
# 2      Hepatitis C virus (isolate 1)               1  0.22Å             198
# 3       Hepatitis C virus subtype 1a               1  0.22Å             198
# 4                      Hepacivirus C               1  0.22Å             198
# ...                              ...             ...    ...             ...
# 16159                   Homo sapiens               1  1.30Å              50
# 16160                   Homo sapiens               1  1.30Å              43
# 16161                   Homo sapiens               2  2.10Å            1521
# 16162                   Homo sapiens               2  2.09Å            1530
# 16163                   Homo sapiens               2  2.42Å            1519
#
#       sequence_id
# 0            100%
# 1            100%
# 2             98%
# 3             99%
# 4             99%
# ...           ...
# 16159         30%
# 16160         28%
# 16161        100%
# 16162         99%
# 16163         99%
#
# [16164 rows x 8 columns]

# %%
all_proteins_df.to_csv("3m5l_proteins.csv", index=False)

# %%
all_proteins_df.iloc[93]
# Out:
# name                                                            3E90
# seed_protein                                                    3M5L
# description        West Nile Vi Rus Ns2b-Ns3protease In Complexed...
# taxonomy                                             West Nile virus
# aligned_protein                                                    1
# rmsd                                                           2.82Å
# aligned_residue                                                  129
# sequence_id                                                      16%
# Name: 93, dtype: object

# %% [markdown]
# Rule 1: > 90% sequence identity - toss it out
# Rule 2: # aligned residues < 50 - toss it out
# Rule 3: RMSD < 2 ang AND # aligned residues > n (50? 60? 70?) - don't iterate
#
# Rule *: # aligned residues > 50% of original protein length
